# %% [markdown]
# <a href="https://colab.research.google.com/github/surajgazi100/Cancer-detection/blob/master/Regex.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![312.jpg](data:image/jpeg;base64,...)

# %%
import re

# %%
import re

txt = "The rain in Spain"
x = re.search("^The.*Spain$", txt)

# %%
import re

txt = "The rain in Spain"
x = re.search("ai", txt)
print(x) #this will print an object
# Out:
# <_sre.SRE_Match object; span=(5, 7), match='ai'>

# %%
import re

txt = "The rain in Spain"
x = re.search(r"\bS\w+", txt)
print(x.string)
# Out:
# The rain in Spain

# %%
import re

txt = "The rain in Spain"
x = re.search(r"\bS\w+", txt)
print(x.group())
# Out:
# Spain

# %%
import re

txt = "The rain in Spain"
x = re.sub("\s", "9", txt, 2)
print(x)
# Out:
# The9rain9in Spain

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![313.jpg](data:image/jpeg;base64,...)
